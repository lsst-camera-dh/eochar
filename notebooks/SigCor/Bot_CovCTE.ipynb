# %% [markdown]
# #  Study of signal correlation in raft
# Goal : This Notebook will generate plots allowing to perform a diagnostic on the signal Covariance between pixels inside a ccd channels to coplement CTE and full well study  in BOT data .
#
# Author : P.Antilogus
#
# Version : 30th November 2020 17:50
#
# New : To be run  at NCSA

# %%
# %matplotlib inline

# system imports
import os
import time
from sys import exit 
import glob

#  Specific package (display , pyfits ..) 
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as pyfits
# Firefly client imports   
#from IPython.display import IFrame
import matplotlib
matplotlib.rcParams['figure.dpi'] = 120

# LSST stack imports
from lsst.daf.persistence import Butler
import lsst.afw.display as afwDisplay
from lsst.ip.isr import IsrTask
import lsst.afw.geom as afwGeom
import lsst.afw.math as afwMath

# %%
# do we use the eotest resultes for the gain
display_in_electron=True
#
if display_in_electron :
    try : 
        from get_EO_analysis_results import get_EO_analysis_results
        from get_EO_analysis_files import get_EO_analysis_files
        from exploreFocalPlane import exploreFocalPlane
        from exploreRaft import exploreRaft
        from eTraveler.clientAPI.connection import Connection
        g = get_EO_analysis_results(db=DB_key[data_to_select['Data_location']])
        eotest_db=True
    except:
        print('No access to eotest DB , so the gain of all devices will be set to 1 ( 1 ADU counted as 1 e- )')
        eotest_db=False
else :
    eotest_db=False
    
# load the frame analysis code 
# %run -i  /home/antilog/repos/eochar/python/lsst/eochar/bot_frame_op.py

# activate the butler
BOT_REPO_DIR = '/lsstdata/offline/teststand/BOT/gen2repo'
butler = Butler(BOT_REPO_DIR)
# Out:
# Warning, Data Catalog not available
# No module named 'datacat'
# No access to eotest DB , so the gain of all devices will be set to 1 ( 1 ADU counted as 1 e- )

# %%
# CONFIGURATION FOR THE CURRENT EXECUTION  ========================================
# ---- raft and associated run ============ To be updated if needed 
# 'raft' :  list of raft 
# 'run' :  list of run , ex : ['9876','9874']  (remark : run is a string )   for all run of this raft : '*' 
# 'sensor' :  list of sensor , ex ['S00','S01','S02'] 
# amplifier : list of amplifier , ex [1,2]  , for 1 to 16 you can use [-1] instead 
run_all=['12845','12849','12851','12857','12860']
#,'12606']
#
raft_itl=['R01', 'R02', 'R03', 'R10', 'R20', 'R41', 'R42', 'R43']
raft_e2v=['R11', 'R12', 'R13', 'R14', 'R21', 'R22', 'R23', 'R24', 'R30', 'R31', 'R32', 'R33', 'R34']
sensors_raft=['S00','S01','S02','S10','S11','S12','S20','S21','S22']
raft_corner=['R00','R04','R40','R44']
sensors_corner=['SG0','SG1','SW0','SW1']
sensors_8ch=['SW0','SW1']
segments=['10','11','12','13','14','15','16','17','07','06','05','04','03','02','01','00']

#
all_sensors={}
all_good_sensors={}
#
for raft in raft_itl+raft_e2v:
    all_sensors[raft]=sensors_raft
    all_good_sensors[raft]={}
    for sensor in sensors_raft:
        all_good_sensors[raft][sensor]=True
for raft in raft_corner:
    all_sensors[raft]=sensors_corner
    all_good_sensors[raft]={}
    for sensor in sensors_corner:
        all_good_sensors[raft][sensor]=True
#
amplifier=[-1]
#
raft=raft_itl+raft_corner+raft_e2v
#raft=raft_e2v
#raft=raft_corner
#raft=['R03']
#raft=['R10','R11','R12','R20','R21','R22','R30','R31','R32']
#raft=['R00']
##

# output file directory
output_data='/home/antilog/DATA/20'
#
# colors for each channel setup
cmap=plt.get_cmap('gist_ncar')
colors=[cmap(j)[:3] for j in np.linspace(0,1,17)]

# %%
number_of_pair_max=150
run_visits=np.zeros((len(run_all),number_of_pair_max,2))
time_visits=np.zeros((len(run_all),number_of_pair_max))
number_of_pair_per_run=np.zeros((len(run_all)),dtype=np.int16)
run=[]
irun=0
for run_cur in run_all :
    # select only bias inages 
    visits=butler.queryMetadata('raw', ['visit'], dataId={'run':run_cur,'testType': 'FLAT','imageType': 'FLAT'})
    if len(visits) < 2 : 
        print('No enough good flat in run ',run_cur)
    else :
        visits.sort()
        good_visits = []
        ptim=[]
        visit1=0
        for ivisit in range(len(visits)) :
            if visit1==0 : 
                visit1=visits[ivisit]
                continue
            visit2=visits[ivisit]
            #
            dId = {'visit': visit1, 'detector': 2}
            raw1 = butler.get('raw', **dId)
            time1 = raw1.getInfo().getVisitInfo().getExposureTime()

            # Get ISR data for second image
            dId = {'visit': visit2, 'detector': 2}
            raw2 = butler.get('raw', **dId)
            time2 = raw2.getInfo().getVisitInfo().getExposureTime()
            if abs(time1 - time2) > 0.01:
                print("Mismatched exptimes ",visit1,time1,visit2,time2)
                visit1=visits[ivisit]
                continue
            else :
                good_visits.append((visit1,visit2))
                ptim.append(time1)
                visit1=0
        if len(ptim)==0 :
            print('No enough good flat in run', run_cur )
            continue
        ltim=np.array(ptim)
        # if 2 series of increasing eexposure time , we only usee teh second one ( larger flux )
        for it in range(1,len(ptim)):
            if ltim[it] < ltim[it-1] : break
        if it == len(ptim)-1 : it=0
        # for CTE study we skip exposure with neutral filter 
        run.append(run_cur)
        number_of_pair_per_run[irun]=len(ptim)-it
        run_visits[irun,:number_of_pair_per_run[irun],:]=np.array(good_visits[it:][:])
        time_visits[irun,:number_of_pair_per_run[irun]]=ltim[it:]
        irun+=1
        #number_of_pair_per_run=2
        print('Run=',run_cur,' Time distribution of the #pair ',ltim[it:])
#
number_of_raft=len(raft)
number_of_run=len(run)
# set the max value for the tables creation
number_of_sensor=len(sensors_raft)
#how many amplifiers 
if -1 in amplifier :
    amplifier_list=np.array(range(1,17))
else :
    amplifier_list=np.array(amplifier)
amplifier_list.sort()
number_of_amplifier=len(amplifier_list)
if number_of_run < 1 : 
    print('No data found')
    raise
# Out:
# Run= 12845  Time distribution of the #pair  [  8.25466  12.0721   17.6542   25.8167   39.4771   44.1367   49.3477
#   55.1732   61.6869   68.9704   77.1132   86.2166   96.3951  107.775
#  120.5     134.725   150.63    168.413   188.296   210.526   235.381
#  263.169   294.239   328.976   369.208   539.912  ]
# Run= 12849  Time distribution of the #pair  [  8.25466  12.0721   17.6542   25.8167   39.4771   44.1367   49.3477
#   55.1732   61.6869   68.9704   77.1132   86.2166   96.3951  107.775
#  120.5     134.725   150.63    168.413   188.296   210.526   235.381
#  263.169   294.239   328.976   369.208   539.912  ]
# Run= 12851  Time distribution of the #pair  [  8.25466  12.0721   17.6542   25.8167   39.4771   44.1367   49.3477
#   55.1732   61.6869   68.9704   77.1132   86.2166   96.3951  107.775
#  120.5     134.725   150.63    168.413   188.296   210.526   235.381
#  263.169   294.239   328.976   369.208   539.912  ]
# Run= 12857  Time distribution of the #pair  [  8.25466  12.0721   17.6542   25.8167   39.4771   44.1367   49.3477
#   55.1732   61.6869   68.9704   77.1132   86.2166   96.3951  107.775
#  120.5     134.725   150.63    168.413   188.296   210.526   235.381
#  263.169   294.239   328.976   369.208   539.912  ]
# No enough good flat in run  12860

# %%
def find_pair(raft_cur,all_good_sensors):
    # compute the noise per image
    # Do all the fft plots if asked 
    # intialisation 
    number_of_raft_sensor=len(all_sensors[raft_cur])
    #
    all_file=np.zeros((number_of_run,number_of_raft_sensor,number_of_pair_max,2),dtype=np.object_)
    #
    first_ccd_run0=-1
    #
    for irun in range(len(run)) : 
        run_cur=run[irun]
        #
        #
        t0=0
        #
        for iccd in range(number_of_raft_sensor) : 
            #
            for it in range(number_of_pair_per_run[irun]) : 
                for ifile in range(2) : 
                    dataId2 = {'visit': run_visits[irun,it,ifile], 'detectorName': all_sensors[raft_cur][iccd], 'raftName': raft_cur}
                    try : 
                        file=butler.get('raw_filename', dataId2)[0][:-3]
                    except : 
                        print('Error , data not found : ',dataId2)
                        all_good_sensors[raft_cur][all_sensors[raft_cur][iccd]]=False
                        break
                    if irun==0 and first_ccd_run0<0: first_ccd_run0=iccd
                    all_file[irun,iccd,it,ifile]=file
    return  all_file , first_ccd_run0

# %%
def cov_in_raft(raft_cur,all_file, first_ccd_run0 ,show=True):
    #
    if raft_cur in raft_corner :
        nb_amp_in_raft=48
    else :
        nb_amp_in_raft=144
    #
    number_of_raft_sensor=len(all_sensors[raft_cur])
    #  
    # we grant the image size to split in 5 in // and serial direction 
    line_split=5
    serial_split=5 
    # get the amplifier shape for this raft
    fits=pyfits.open(all_file[0,first_ccd_run0 ,0,0])
    first_line,first_p_over,first_col,first_s_over=image_area(fits)
    fits.close()
    #ncol=len(fits[1].data[100,:])
    #nline==len(fits[1].data[:,100])
    if first_p_over-first_line == 2000 :
        # itl 
        xf=first_col+19
        xl=first_s_over-20
        yf=first_line+50
        yl=first_p_over-20
    else :
        #e2v 
        xf=first_col+21
        xl=first_s_over-21
        yf=first_line+50
        yl=first_p_over-22

#
    yl1=yl+1
    xl1=xl+1
    ncol=xl-xf
    nline=yl-yf
    #
    flux=np.zeros((number_of_run,9,number_of_pair_max,16))
    #
    nflux=np.zeros((number_of_run,9,16),dtype=np.int16)
    # covar 10 and 01 measured in 5 image slices 
    covars=np.zeros((number_of_run,9,number_of_pair_max,16,serial_split))
    covarp=np.zeros((number_of_run,9,number_of_pair_max,16,line_split))
    # covar 10 and 01 measured on the full  image
    covarst=np.zeros((number_of_run,9,number_of_pair_max,16))
    covarpt=np.zeros((number_of_run,9,number_of_pair_max,16))
    # ratio of covar 10 and 01 
    covarps=np.zeros((number_of_run,9,number_of_pair_max,16))
    #
    for irun in range(number_of_run) :
        # 
        for iccd in range(number_of_raft_sensor) :
#        for iccd in [6] :
            if not(all_good_sensors[raft_cur][all_sensors[raft_cur][iccd]]) :
                continue
            if ( all_sensors[raft_cur][iccd] in sensors_8ch ):
                number_of_amp_sensor=8
            else : 
                    number_of_amp_sensor=16
            for ipair in range(number_of_pair_per_run[irun]) :
                #
                fname=[all_file[irun,iccd,ipair,0],all_file[irun,iccd,ipair,1]]
                all=InFile(dirall=fname,Slow=False,verbose=False)
                #
                for k in range(number_of_amp_sensor) :
                    # did we pass the ultra saturation state : stop
                    if ipair >  nflux[irun,iccd,k] : 
                        # set it anyway , to have a simple way to estimate min-max flux per sensor
                        flux[irun,iccd,ipair,k]=flux[irun,iccd,ipair-1,k] 
                        continue
                    # select-truncate  the image for the channel ch_cur
                    Im0=np.median(all.all_file[0].Image[k][yf:yl1,xf:xl1])
                    Im1=np.median(all.all_file[1].Image[k][yf:yl1,xf:xl1])
                    ImDiff=((all.all_file[0].Image[k][yf:yl1,xf:xl1]/Im0-all.all_file[1].Image[k][yf:yl1,xf:xl1]/Im1)*(Im0+Im1)/2.)
                    flux[irun,iccd,ipair,k]=(Im0+Im1)/2.
                    # we are in a ultra saturation : stop 
                    if ipair>0 and flux[irun,iccd,ipair,k]<flux[irun,iccd,ipair-1,k] : 
                        flux[irun,iccd,ipair,k]=flux[irun,iccd,ipair-1,k] 
                        continue
                    nflux[irun,iccd,k]+=1
                    av=np.mean((ImDiff[:,:]))
                    std=np.std((ImDiff[:,:]))
                    gooda= (np.abs(ImDiff-av)<4.*std)
                    nb_gooda=np.sum(gooda)
                    diff_tmean=np.sum(ImDiff*gooda)/nb_gooda
                    # serial
                    good=gooda[:,:-1]*gooda[:,1:]
                # 
                    count=np.sum(np.sum(np.split(good,serial_split,axis=1),axis=2),axis=1)
                    countt=np.sum(good)
                #
                #   as it's computed from an image diff , we have to  /2 , 
                #   and we will plot in .1% unit , so we *1000
                    covars[irun,iccd,ipair,k,:]=np.sum(np.sum(np.split((ImDiff[:,:-1]-diff_tmean)
                                                *(ImDiff[:,1:]-diff_tmean)*good,serial_split,axis=1)
                                                ,axis=2),axis=1)/count/flux[irun,iccd,ipair,k]/2.*1000.
                    covarst[irun,iccd,ipair,k]=np.sum((ImDiff[:,:-1]-diff_tmean)
                                                *(ImDiff[:,1:]-diff_tmean)*good
                                                )/countt/flux[irun,iccd,ipair,k]/2.*1000.
                    
                #   //
                    good=gooda[:-1,:]*gooda[1:,:]
                # 
                    count=np.sum(np.sum(np.split(good,line_split,axis=0),axis=2),axis=1)
                #
                #   as it's computed from an image diff , we have to  /2 , 
                #   and we will plot in .1% unit , so we *1000
                    covarp[irun,iccd,ipair,k,:]=np.sum(np.sum(np.split((ImDiff[:-1,:]-diff_tmean)
                                                *(ImDiff[1:,:]-diff_tmean)*good,line_split,axis=0)
                                                ,axis=2),axis=1)/count/flux[irun,iccd,ipair,k]/2.*1000.
                    covarpt[irun,iccd,ipair,k]=np.sum((ImDiff[:-1,:]-diff_tmean)
                                                *(ImDiff[1:,:]-diff_tmean)*good
                                                )/countt/flux[irun,iccd,ipair,k]/2.*1000.
                # ratio of covar 
                    covarps[irun,iccd,ipair,k]= covarpt[irun,iccd,ipair,k]/covarst[irun,iccd,ipair,k]  
            for k in range(number_of_amp_sensor) :
                # per amplifier  plot , serial , // & ratio 
                # flux max min per sensor 
                flux_max=np.max(flux[irun,iccd,:nflux[irun,iccd,k],:number_of_amp_sensor])*1.1 
                #flux_min=min(1100,np.min(flux[irun,iccd,:nflux[irun,iccd,k],:number_of_amp_sensor]))*.9
                #
                fig=plt.figure(figsize=[15,15])
                title='covariance  vs flux for : raft=%s  ccd=%s Seg=%s (Hdu=%d) for run %s' %(raft_cur,all_sensors[raft_cur][iccd],segments[k],k+1,run[irun])
                fig.suptitle(title)
                title='cov(1,0) '
                fig.add_subplot(2,3,1,title=title)
                for isplit in range(serial_split) :
                    label='%d/%d serial fraction' %(isplit+1,serial_split)
                    plt.plot(flux[irun,iccd,:nflux[irun,iccd,k],k],covars[irun,iccd,:nflux[irun,iccd,k],k,isplit],label=label)
                label='full image' 
                plt.plot(flux[irun,iccd,:nflux[irun,iccd,k],k],covarst[irun,iccd,:nflux[irun,iccd,k],k],label=label)
                plt.ylabel('cov(1,0)/flux * 1000. ')
                plt.xlabel('flux in ADU')
                plt.legend(bbox_to_anchor=(1.05, 1),loc=2, borderaxespad=0.)
                plt.yscale('symlog')
                plt.xlim(0.,flux_max)
                plt.ylim(0.)
                plt.ticklabel_format(axis='x',style='sci', scilimits=(0,0))
                #plt.xscale('symlog')
                plt.grid(color='grey',linestyle='dotted',which='major',axis='both')
                title='cov(0,1)'
                fig.add_subplot(2,3,3,title=title)
                for isplit in range(serial_split) :
                    label='%d/%d // fraction' %(isplit+1,serial_split)
                    plt.plot(flux[irun,iccd,:nflux[irun,iccd,k],k],covarp[irun,iccd,:nflux[irun,iccd,k],k,isplit],label=label)
                label='full image' 
                plt.plot(flux[irun,iccd,:nflux[irun,iccd,k],k],covarpt[irun,iccd,:nflux[irun,iccd,k],k],label=label)
                plt.ylabel('cov(0,1)/flux * 1000. ')
                plt.xlabel('flux in ADU')
                plt.legend(bbox_to_anchor=(1.05, 1),loc=2, borderaxespad=0.)
                plt.yscale('symlog')
                plt.xlim(0.,flux_max)
                plt.ylim(0.)
                plt.ticklabel_format(axis='x',style='sci', scilimits=(0,0))
                #plt.xscale('symlog')
                plt.grid(color='grey',linestyle='dotted',which='major',axis='both')
                title='cov(0,1)/cov(1,0)'
                fig.add_subplot(2,3,5,title=title)
                plt.plot(flux[irun,iccd,:nflux[irun,iccd,k],k],covarps[irun,iccd,:nflux[irun,iccd,k],k])
                plt.ylabel('cov(0,1)/cov(1,0) ')
                plt.xlabel('flux in ADU')
                plt.xlim(0.,flux_max)
                plt.ylim(0.)
                plt.ticklabel_format(axis='x',style='sci', scilimits=(0,0))
                #plt.xscale('symlog')
                plt.grid(color='grey',linestyle='dotted',which='major',axis='both')
                #plt.show()
                if show : plt.show()
                hdu='%d' % (k+1)
                root_plt=os.path.join(output_data,run[irun],raft_cur,all_sensors[raft_cur][iccd],hdu)
                os.makedirs(root_plt,exist_ok=True)
                plotfile=os.path.join(root_plt,'Cov_vs_Flux.png')
                print (plotfile)
                fig.savefig(plotfile,bbox_inches='tight')
                plt.close(fig) 
        # flux max min per sensor 
            flux_max=np.max(flux[irun,iccd,:number_of_pair_per_run[irun],:number_of_amp_sensor])*1.1 
            #flux_min=min(1100,np.min(flux[irun,iccd,:number_of_pair_per_run[irun],:number_of_amp_sensor]))*.9
        # per CCD plot , serial 
            fig=plt.figure(figsize=[15,15])
            fig.suptitle('cov(1,0)/Flux vs flux per slice of serial register : '+raft_cur+' ccd '+all_sensors[raft_cur][iccd]+' for run '+run[irun])
            #
            for k in range(number_of_amp_sensor) :
                title=' Seg=%s (Hdu=%d)' %(segments[k],k+1)
                fig.add_subplot(4,4,k+1,title=title)
                for isplit in range(serial_split) :
                    label='%d/%d serial fraction' %(isplit+1,serial_split)
                    plt.plot(flux[irun,iccd,:nflux[irun,iccd,k],k],covars[irun,iccd,:nflux[irun,iccd,k],k,isplit],label=label)
                label='full image' 
                plt.plot(flux[irun,iccd,:nflux[irun,iccd,k],k],covarst[irun,iccd,:nflux[irun,iccd,k],k],label=label)
                if k%4==0 :
                    plt.ylabel('cov(1,0)/flux * 1000. ')
                if k-number_of_amp_sensor>-5 :
                    plt.xlabel('flux in ADU')
                if (k+1)%4 ==0 :
                    plt.legend(bbox_to_anchor=(1.05, 1),loc=2, borderaxespad=0.)
                plt.yscale('symlog')
                plt.xlim(0,flux_max)
                plt.ylim(0.)
                plt.ticklabel_format(axis='x',style='sci', scilimits=(0,0))
                #plt.xscale('symlog')
                plt.grid(color='grey',linestyle='dotted',which='major',axis='both')
                #plt.xlim(-1.,1000.)
            #plt.show()
            if show : plt.show()
            root_plt=os.path.join(output_data,run[irun],raft_cur,all_sensors[raft_cur][iccd])
            os.makedirs(root_plt,exist_ok=True)
            plotfile=os.path.join(root_plt,'Cov10_vs_Flux.png')
            print (plotfile)
            fig.savefig(plotfile,bbox_inches='tight')
            plt.close(fig) 
        # per CCD plot , // 
            fig=plt.figure(figsize=[15,15])
            fig.suptitle('cov(0,1)/Flux vs flux per slice of column : '+raft_cur+' ccd '+all_sensors[raft_cur][iccd]+' for run '+run[irun])
            #
            for k in range(number_of_amp_sensor) :
                title=' Seg=%s (Hdu=%d)' %(segments[k],k+1)
                fig.add_subplot(4,4,k+1,title=title)
                for isplit in range(serial_split) :
                    label='%d/%d // fraction' %(isplit+1,serial_split)
                    plt.plot(flux[irun,iccd,:nflux[irun,iccd,k],k],covarp[irun,iccd,:nflux[irun,iccd,k],k,isplit],label=label)
                label='full image' 
                plt.plot(flux[irun,iccd,:nflux[irun,iccd,k],k],covarpt[irun,iccd,:nflux[irun,iccd,k],k],label=label)
                if k%4==0 :
                    plt.ylabel('cov(0,1)/flux * 1000. ')
                if k-number_of_amp_sensor>-5 :
                    plt.xlabel('flux in ADU')
                if (k+1)%4 ==0 :
                    plt.legend(bbox_to_anchor=(1.05, 1),loc=2, borderaxespad=0.)
                plt.yscale('symlog')
                plt.xlim(0.,flux_max)
                plt.ylim(0.)
                plt.ticklabel_format(axis='x',style='sci', scilimits=(0,0))
                #plt.xscale('symlog')
                plt.grid(color='grey',linestyle='dotted',which='major',axis='both')
                 #plt.xlim(-1.,1000.)
            #plt.show()
            if show : plt.show()
            root_plt=os.path.join(output_data,run[irun],raft_cur,all_sensors[raft_cur][iccd])
            os.makedirs(root_plt,exist_ok=True)
            plotfile=os.path.join(root_plt,'Cov01_vs_Flux.png')
            print (plotfile)
            fig.savefig(plotfile,bbox_inches='tight')
            plt.close(fig) 
        # per CCD plot , // / serial 
            fig=plt.figure(figsize=[15,15])
            fig.suptitle('cov(0,1)/cov(1,0) vs flux  : '+raft_cur+' ccd '+all_sensors[raft_cur][iccd]+' for run '+run[irun])
            #
            for k in range(number_of_amp_sensor) :
                title=' Seg=%s (Hdu=%d)' %(segments[k],k+1)
                fig.add_subplot(4,4,k+1,title=title)
                plt.plot(flux[irun,iccd,:nflux[irun,iccd,k],k],covarps[irun,iccd,:nflux[irun,iccd,k],k])
                if k%4==0 :
                    plt.ylabel('cov(0,1)/cov(1,0) ')
                if k-number_of_amp_sensor>-5 :
                    plt.xlabel('flux in ADU')
                plt.xlim(0.,flux_max)
                ymax=min(20.,np.max(covarps[irun,iccd,:nflux[irun,iccd,k],k]))*1.1
                plt.ylim(0.,ymax)
                plt.ticklabel_format(axis='x',style='sci', scilimits=(0,0))
                #plt.xscale('symlog')
                plt.grid(color='grey',linestyle='dotted',which='major',axis='both')
                #plt.xlim(-1.,1000.)
            #plt.show()
            if show : plt.show()
            root_plt=os.path.join(output_data,run[irun],raft_cur,all_sensors[raft_cur][iccd])
            os.makedirs(root_plt,exist_ok=True)
            plotfile=os.path.join(root_plt,'Cov_01div10_vs_Flux.png')
            print (plotfile)
            fig.savefig(plotfile,bbox_inches='tight')
            plt.close(fig) 

        # per raft plot 
        if raft_cur in raft_corner :
            corner=True
        else :
            corner=False
        # per CCD plot , // / serial 
        fig=plt.figure(figsize=[15,15])
        fig.suptitle('cov(0,1)/cov(1,0) vs flux  : '+raft_cur+' for run '+run[irun])
        #
        ifig=0
        for iccd in range(number_of_raft_sensor) :
#
            ifig+=1
            if corner and iccd==2 :
                ifig+=1
            if not(all_good_sensors[raft_cur][all_sensors[raft_cur][iccd]]) :
                continue
            ax=fig.add_subplot(3,3,ifig,title=all_sensors[raft_cur][iccd])        
#        for iccd in [6] :
            if ( all_sensors[raft_cur][iccd] in sensors_8ch ):
                number_of_amp_sensor=8
            else : 
                    number_of_amp_sensor=16  
            for k in range(number_of_amp_sensor) :
                label='Seg. %s (Hdu=%d)' % (segments[k],k+1)    
                plt.plot(flux[irun,iccd,:nflux[irun,iccd,k],k],covarps[irun,iccd,:nflux[irun,iccd,k],k],color=colors[k],label=label)
        # flux max min per sensor 
            flux_max=np.max(flux[irun,iccd,:number_of_pair_per_run[irun],:number_of_amp_sensor])*1.1 
            #flux_min=min(1100,np.min(flux[irun,iccd,:number_of_pair_per_run[irun],:number_of_amp_sensor]))*.9
        #
            if iccd%3==0 or corner :
                plt.ylabel('cov(0,1)/cov(1,0) ')
            if iccd-number_of_raft_sensor>-4 or corner :
                plt.xlabel('flux in ADU')
            plt.xlim(0.,flux_max)
            ymax=min(20.,np.max(covarps[irun,iccd,:number_of_pair_per_run[irun],:]))*1.1
            plt.ylim(0.,ymax)
            plt.ticklabel_format(axis='x',style='sci', scilimits=(0,0))
            #plt.xscale('symlog')
            plt.grid(color='grey',linestyle='dotted',which='major',axis='both')
            if corner :
                if iccd%2 ==1 : plt.legend(bbox_to_anchor=(1.05, 1),loc=2, borderaxespad=0.)
            elif iccd==2 :
                plt.legend(bbox_to_anchor=(1.05, 1),loc=2, borderaxespad=0.)
        if show : plt.show()
        root_plt=os.path.join(output_data,run[irun],raft_cur)
        os.makedirs(root_plt,exist_ok=True)
        plotfile=os.path.join(root_plt,'Cov_01div10_vs_Flux.png')
        print (plotfile)
        fig.savefig(plotfile,bbox_inches='tight')
        plt.close(fig) 

    return 
#    return     flux,covars,covarp

# %%
#noise=np.zeros((number_of_raft,number_of_run,number_of_sensor*16)) 
#noise_std=np.zeros((number_of_raft,number_of_run,number_of_sensor*16)) 
#cor=np.zeros((number_of_raft,number_of_run,144,144))
#
for iraft in range(len(raft)) :
    raft_cur=raft[iraft]
    # find all the files to compute the correlation between channels
    all_file, first_ccd_run0=find_pair(raft_cur,all_good_sensors)
    # do all the cov plots for this raft and all run 
#    flux,covars,covarp=cov_in_raft(raft_cur,all_file,show=False)
    if first_ccd_run0>-1 : cov_in_raft(raft_cur,all_file, first_ccd_run0,show=False)
    #
# Out:
# /home/antilog/DATA/20/12845/R11/S00/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S00/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S00/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S00/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S00/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S00/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S00/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S00/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S00/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S00/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S00/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S00/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S00/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S00/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S00/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S00/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S00/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S00/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S00/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S01/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S01/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S01/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S01/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S01/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S01/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S01/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S01/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S01/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S01/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S01/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S01/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S01/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S01/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S01/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S01/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S01/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S01/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S01/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S02/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S02/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S02/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S02/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S02/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S02/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S02/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S02/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S02/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S02/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S02/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S02/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S02/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S02/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S02/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S02/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S02/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S02/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S02/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S10/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S10/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S10/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S10/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S10/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S10/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S10/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S10/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S10/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S10/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S10/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S10/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S10/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S10/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S10/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S10/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S10/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S10/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S10/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S11/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S11/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S11/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S11/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S11/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S11/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S11/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S11/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S11/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S11/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S11/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S11/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S11/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S11/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S11/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S11/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S11/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S11/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S11/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S12/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S12/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S12/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S12/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S12/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S12/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S12/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S12/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S12/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S12/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S12/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S12/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S12/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S12/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S12/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S12/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S12/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S12/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S12/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S20/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S20/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S20/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S20/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S20/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S20/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S20/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S20/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S20/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S20/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S20/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S20/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S20/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S20/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S20/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S20/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S20/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S20/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S20/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S21/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S21/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S21/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S21/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S21/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S21/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S21/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S21/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S21/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S21/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S21/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S21/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S21/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S21/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S21/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S21/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S21/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S21/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S21/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S22/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S22/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S22/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S22/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S22/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S22/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S22/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S22/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S22/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S22/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S22/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S22/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S22/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S22/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S22/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S22/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S22/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S22/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/S22/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12845/R11/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S00/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S00/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S00/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S00/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S00/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S00/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S00/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S00/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S00/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S00/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S00/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S00/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S00/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S00/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S00/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S00/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S00/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S00/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S00/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S01/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S01/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S01/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S01/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S01/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S01/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S01/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S01/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S01/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S01/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S01/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S01/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S01/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S01/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S01/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S01/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S01/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S01/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S01/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S02/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S02/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S02/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S02/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S02/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S02/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S02/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S02/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S02/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S02/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S02/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S02/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S02/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S02/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S02/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S02/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S02/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S02/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S02/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S10/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S10/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S10/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S10/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S10/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S10/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S10/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S10/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S10/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S10/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S10/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S10/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S10/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S10/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S10/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S10/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S10/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S10/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S10/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S11/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S11/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S11/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S11/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S11/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S11/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S11/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S11/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S11/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S11/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S11/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S11/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S11/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S11/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S11/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S11/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S11/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S11/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S11/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S12/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S12/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S12/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S12/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S12/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S12/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S12/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S12/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S12/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S12/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S12/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S12/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S12/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S12/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S12/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S12/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S12/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S12/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S12/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S20/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S20/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S20/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S20/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S20/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S20/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S20/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S20/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S20/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S20/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S20/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S20/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S20/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S20/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S20/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S20/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S20/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S20/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S20/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S21/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S21/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S21/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S21/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S21/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S21/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S21/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S21/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S21/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S21/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S21/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S21/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S21/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S21/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S21/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S21/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S21/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S21/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S21/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S22/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S22/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S22/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S22/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S22/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S22/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S22/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S22/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S22/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S22/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S22/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S22/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S22/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S22/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S22/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S22/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S22/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S22/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/S22/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12849/R11/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S00/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S00/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S00/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S00/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S00/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S00/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S00/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S00/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S00/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S00/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S00/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S00/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S00/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S00/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S00/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S00/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S00/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S00/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S00/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S01/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S01/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S01/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S01/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S01/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S01/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S01/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S01/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S01/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S01/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S01/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S01/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S01/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S01/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S01/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S01/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S01/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S01/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S01/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S02/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S02/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S02/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S02/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S02/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S02/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S02/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S02/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S02/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S02/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S02/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S02/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S02/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S02/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S02/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S02/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S02/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S02/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S02/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S10/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S10/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S10/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S10/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S10/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S10/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S10/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S10/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S10/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S10/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S10/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S10/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S10/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S10/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S10/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S10/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S10/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S10/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S10/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S11/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S11/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S11/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S11/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S11/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S11/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S11/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S11/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S11/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S11/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S11/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S11/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S11/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S11/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S11/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S11/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S11/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S11/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S11/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S12/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S12/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S12/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S12/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S12/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S12/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S12/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S12/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S12/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S12/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S12/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S12/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S12/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S12/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S12/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S12/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S12/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S12/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S12/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S20/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S20/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S20/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S20/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S20/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S20/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S20/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S20/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S20/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S20/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S20/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S20/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S20/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S20/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S20/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S20/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S20/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S20/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S20/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S21/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S21/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S21/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S21/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S21/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S21/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S21/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S21/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S21/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S21/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S21/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S21/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S21/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S21/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S21/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S21/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S21/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S21/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S21/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S22/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S22/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S22/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S22/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S22/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S22/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S22/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S22/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S22/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S22/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S22/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S22/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S22/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S22/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S22/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S22/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S22/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S22/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/S22/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12851/R11/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S00/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S00/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S00/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S00/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S00/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S00/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S00/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S00/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S00/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S00/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S00/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S00/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S00/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S00/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S00/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S00/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S00/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S00/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S00/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S01/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S01/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S01/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S01/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S01/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S01/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S01/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S01/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S01/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S01/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S01/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S01/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S01/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S01/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S01/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S01/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S01/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S01/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S01/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S02/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S02/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S02/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S02/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S02/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S02/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S02/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S02/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S02/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S02/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S02/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S02/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S02/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S02/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S02/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S02/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S02/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S02/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S02/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S10/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S10/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S10/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S10/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S10/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S10/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S10/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S10/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S10/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S10/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S10/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S10/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S10/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S10/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S10/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S10/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S10/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S10/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S10/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S11/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S11/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S11/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S11/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S11/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S11/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S11/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S11/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S11/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S11/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S11/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S11/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S11/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S11/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S11/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S11/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S11/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S11/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S11/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S12/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S12/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S12/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S12/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S12/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S12/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S12/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S12/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S12/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S12/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S12/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S12/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S12/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S12/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S12/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S12/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S12/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S12/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S12/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S20/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S20/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S20/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S20/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S20/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S20/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S20/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S20/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S20/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S20/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S20/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S20/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S20/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S20/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S20/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S20/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S20/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S20/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S20/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S21/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S21/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S21/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S21/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S21/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S21/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S21/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S21/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S21/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S21/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S21/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S21/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S21/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S21/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S21/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S21/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S21/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S21/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S21/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S22/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S22/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S22/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S22/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S22/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S22/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S22/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S22/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S22/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S22/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S22/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S22/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S22/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S22/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S22/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S22/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S22/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S22/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/S22/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12857/R11/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S00/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S00/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S00/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S00/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S00/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S00/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S00/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S00/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S00/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S00/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S00/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S00/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S00/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S00/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S00/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S00/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S00/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S00/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S00/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S01/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S01/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S01/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S01/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S01/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S01/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S01/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S01/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S01/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S01/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S01/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S01/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S01/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S01/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S01/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S01/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S01/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S01/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S01/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S02/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S02/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S02/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S02/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S02/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S02/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S02/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S02/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S02/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S02/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S02/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S02/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S02/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S02/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S02/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S02/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S02/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S02/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S02/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S10/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S10/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S10/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S10/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S10/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S10/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S10/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S10/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S10/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S10/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S10/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S10/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S10/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S10/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S10/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S10/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S10/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S10/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S10/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S11/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S11/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S11/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S11/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S11/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S11/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S11/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S11/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S11/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S11/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S11/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S11/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S11/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S11/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S11/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S11/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S11/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S11/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S11/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S12/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S12/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S12/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S12/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S12/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S12/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S12/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S12/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S12/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S12/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S12/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S12/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S12/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S12/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S12/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S12/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S12/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S12/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S12/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S20/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S20/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S20/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S20/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S20/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S20/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S20/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S20/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S20/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S20/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S20/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S20/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S20/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S20/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S20/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S20/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S20/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S20/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S20/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S21/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S21/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S21/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S21/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S21/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S21/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S21/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S21/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S21/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S21/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S21/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S21/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S21/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S21/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S21/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S21/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S21/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S21/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S21/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S22/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S22/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S22/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S22/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S22/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S22/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S22/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S22/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S22/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S22/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S22/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S22/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S22/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S22/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S22/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S22/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S22/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S22/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/S22/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12845/R12/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12849/R12/S00/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R12/S00/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R12/S00/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R12/S00/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R12/S00/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R12/S00/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R12/S00/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R12/S00/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R12/S00/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R12/S00/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R12/S00/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R12/S00/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R12/S00/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R12/S00/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R12/S00/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R12/S00/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12849/R12/S00/Cov10_vs_Flux.png
# ...
# /home/antilog/DATA/20/12851/R34/S02/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S02/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S02/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S02/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S02/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S10/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S10/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S10/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S10/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S10/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S10/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S10/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S10/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S10/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S10/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S10/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S10/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S10/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S10/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S10/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S10/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S10/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S10/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S10/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S11/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S11/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S11/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S11/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S11/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S11/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S11/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S11/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S11/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S11/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S11/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S11/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S11/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S11/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S11/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S11/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S11/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S11/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S11/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S12/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S12/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S12/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S12/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S12/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S12/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S12/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S12/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S12/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S12/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S12/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S12/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S12/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S12/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S12/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S12/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S12/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S12/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S12/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S20/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S20/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S20/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S20/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S20/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S20/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S20/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S20/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S20/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S20/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S20/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S20/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S20/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S20/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S20/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S20/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S20/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S20/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S20/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S21/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S21/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S21/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S21/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S21/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S21/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S21/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S21/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S21/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S21/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S21/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S21/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S21/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S21/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S21/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S21/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S21/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S21/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S21/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S22/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S22/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S22/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S22/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S22/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S22/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S22/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S22/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S22/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S22/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S22/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S22/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S22/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S22/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S22/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S22/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S22/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S22/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/S22/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12851/R34/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S00/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S00/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S00/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S00/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S00/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S00/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S00/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S00/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S00/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S00/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S00/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S00/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S00/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S00/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S00/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S00/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S00/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S00/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S00/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S01/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S01/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S01/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S01/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S01/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S01/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S01/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S01/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S01/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S01/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S01/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S01/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S01/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S01/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S01/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S01/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S01/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S01/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S01/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S02/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S02/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S02/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S02/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S02/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S02/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S02/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S02/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S02/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S02/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S02/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S02/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S02/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S02/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S02/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S02/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S02/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S02/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S02/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S10/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S10/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S10/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S10/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S10/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S10/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S10/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S10/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S10/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S10/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S10/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S10/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S10/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S10/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S10/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S10/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S10/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S10/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S10/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S11/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S11/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S11/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S11/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S11/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S11/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S11/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S11/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S11/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S11/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S11/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S11/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S11/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S11/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S11/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S11/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S11/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S11/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S11/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S12/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S12/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S12/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S12/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S12/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S12/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S12/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S12/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S12/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S12/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S12/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S12/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S12/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S12/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S12/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S12/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S12/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S12/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S12/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S20/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S20/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S20/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S20/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S20/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S20/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S20/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S20/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S20/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S20/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S20/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S20/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S20/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S20/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S20/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S20/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S20/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S20/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S20/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S21/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S21/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S21/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S21/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S21/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S21/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S21/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S21/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S21/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S21/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S21/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S21/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S21/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S21/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S21/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S21/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S21/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S21/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S21/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S22/1/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S22/2/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S22/3/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S22/4/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S22/5/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S22/6/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S22/7/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S22/8/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S22/9/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S22/10/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S22/11/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S22/12/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S22/13/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S22/14/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S22/15/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S22/16/Cov_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S22/Cov10_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S22/Cov01_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/S22/Cov_01div10_vs_Flux.png
# /home/antilog/DATA/20/12857/R34/Cov_01div10_vs_Flux.png
